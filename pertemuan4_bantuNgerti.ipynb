# %% [markdown]
# ### Install pandas dan pemakaian

# %%
# !pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Fundamental Pandas

# %%
data = {
    'Name':['Al','El','Aheng','John'],
    'Age':[20,13,43,14],
    'City':['Balikpapan','Jombang','Atambua','Tomohon']
}

# %%
df=pd.DataFrame(data)

# %%
print(df)
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
df
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
df
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df['Name']
# Out:
# 0       Al
# 1       El
# 2    Aheng
# 3     John
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    20
# 1    13
# 2    43
# 3    14
# Name: Age, dtype: int64

# %%
df['City']
# Out:
# 0    Balikpapan
# 1       Jombang
# 2       Atambua
# 3       Tomohon
# Name: City, dtype: object

# %%
print(df[['Name','Age']])
# Out:
#     Name  Age
# 0     Al   20
# 1     El   13
# 2  Aheng   43
# 3   John   14

# %%
print(df.head())
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
print(df.tail())
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#            Age
# count   4.0000
# mean   22.5000
# std    14.0119
# min    13.0000
# 25%    13.7500
# 50%    17.0000
# 75%    25.7500
# max    43.0000

# %%
print(df['Age'])
# Out:
# 0    20
# 1    13
# 2    43
# 3    14
# Name: Age, dtype: int64

# %%
print(df.iloc[0])
print(df.iloc[3])
# Out:
# Name            Al
# Age             20
# City    Balikpapan
# Name: 0, dtype: object
# Name       John
# Age          14
# City    Tomohon
# Name: 3, dtype: object

# %%
df.iloc[0:2]
# Out:
#   Name  Age        City
# 0   Al   20  Balikpapan
# 1   El   13     Jombang

# %%
df
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %% [markdown]
# ### Filter data

# %%
dfTua=df[df['Age']>25]

# %%
dfTua
# Out:
#     Name  Age     City
# 2  Aheng   43  Atambua

# %%
dfBalikpapan=df[df['City']=='Balikpapan']

# %%
dfBalikpapan
# Out:
#   Name  Age        City
# 0   Al   20  Balikpapan

# %%
#Option 1
dfBalikpapanAge25=df[df['City']=='Balikpapan']
dfBalikpapanAge25=dfBalikpapanAge25[dfBalikpapanAge25['Age']>25]

# %%
#Option 2
dfBalikpapanAge25=df[(df['City']=='Balikpapan') & (df['Age']>25)]

# %%
dfBalikpapanAge25
# Out:
# Empty DataFrame
# Columns: [Name, Age, City]
# Index: []

# %% [markdown]
# ### Add data

# %%
df
# Out:
#     Name  Age        City
# 0     Al   20  Balikpapan
# 1     El   13     Jombang
# 2  Aheng   43     Atambua
# 3   John   14     Tomohon

# %%
salary=[25000,14000,47000,102000]

# %%
df['Salary']=salary

# %%
df
# Out:
#     Name  Age        City  Salary
# 0     Al   20  Balikpapan   25000
# 1     El   13     Jombang   14000
# 2  Aheng   43     Atambua   47000
# 3   John   14     Tomohon  102000

# %% [markdown]
# ### Import csv / data from RAW DATA

# %%
df=pd.read_csv('/content/Dataset E-Commerce.csv')

# %%
df
# Out:
#           id         country             nama                       email  \
# 0       9265          Brasil    Eric Phillips    ericphillips@example.org
# 1       9265          Brasil    Eric Phillips    ericphillips@example.org
# 2       9265          Brasil    Eric Phillips    ericphillips@example.org
# 3       9265          Brasil    Eric Phillips    ericphillips@example.org
# 4      13554          Brasil     Brett Flores     brettflores@example.org
# ...      ...             ...              ...                         ...
# 42032  88693  United Kingdom  Bradley Johnson  bradleyjohnson@example.org
# 42033  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42034  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42035   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
# 42036   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
#
#        order_id  order_date traffic_source               category_product  \
# ...

# %%
df.head()
# Out:
#       id country           nama                     email  order_id  \
# 0   9265  Brasil  Eric Phillips  ericphillips@example.org     11630
# 1   9265  Brasil  Eric Phillips  ericphillips@example.org     11630
# 2   9265  Brasil  Eric Phillips  ericphillips@example.org     11630
# 3   9265  Brasil  Eric Phillips  ericphillips@example.org     11630
# 4  13554  Brasil   Brett Flores   brettflores@example.org     17026
#
#    order_date traffic_source               category_product  \
# 0  2022-12-31         Search                 Sleep & Lounge
# 1  2022-12-31         Search  Fashion Hoodies & Sweatshirts
# 2  2022-12-31         Search            Suits & Sport Coats
# 3  2022-12-31         Search              Outerwear & Coats
# 4  2022-12-18          Email                          Socks
#
#                                         nama_product department_product  \
# 0       Tommy Bahama Men's Cotton Modal V Neck Shirt                Men
# ...

# %%
df.tail()
# Out:
#           id         country             nama                       email  \
# 42032  88693  United Kingdom  Bradley Johnson  bradleyjohnson@example.org
# 42033  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42034  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42035   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
# 42036   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
#
#        order_id  order_date traffic_source               category_product  \
# 42032    111077  2022-03-04         Search                    Tops & Tees
# 42033    123259  2024-04-02         Search                    Tops & Tees
# 42034    123258  2022-02-07         Search                      Maternity
# 42035      8824  2024-04-26        Organic                    Tops & Tees
# 42036      8823  2023-12-23        Organic  Fashion Hoodies & Sweatshirts
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42037 entries, 0 to 42036
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  42037 non-null  int64
#  1   country             42037 non-null  object
#  2   nama                42037 non-null  object
#  3   email               42037 non-null  object
#  4   order_id            42037 non-null  int64
#  5   order_date          42037 non-null  object
#  6   traffic_source      42037 non-null  object
#  7   category_product    42037 non-null  object
#  8   nama_product        42036 non-null  object
#  9   department_product  42037 non-null  object
#  10  brand               42004 non-null  object
#  11  age                 42037 non-null  int64
#  12  gender              42037 non-null  object
#  13  status_order        42037 non-null  object
#  14  registered_date     42037 non-null  object
# ...

# %%
df.describe()
# Out:
#                  id       order_id           age       revenue
# count  42037.000000   42037.000000  42037.000000  42037.000000
# mean   49842.020672   62496.469372     41.091990    111.756239
# std    28877.869564   36096.225860     17.099466    155.923189
# min        4.000000       5.000000     12.000000      0.000000
# 25%    24593.000000   31107.000000     26.000000     33.000000
# 50%    49939.000000   62705.000000     41.000000     64.000000
# 75%    74836.000000   93639.000000     56.000000    130.000000
# max    99998.000000  124992.000000     70.000000   3960.000000

# %%
print(df['age'])
print(df.age)
# Out:
# 0        60
# 1        60
# 2        60
# 3        60
# 4        50
#          ..
# 42032    69
# 42033    44
# 42034    44
# 42035    35
# 42036    35
# Name: age, Length: 42037, dtype: int64
# 0        60
# 1        60
# 2        60
# 3        60
# 4        50
#          ..
# 42032    69
# 42033    44
# 42034    44
# 42035    35
# 42036    35
# Name: age, Length: 42037, dtype: int64

# %%
df.age.value_counts()
# Out:
# age
# 37    847
# 18    779
# 70    774
# 69    770
# 50    770
# 67    768
# 55    766
# 28    763
# 14    763
# 32    761
# 39    761
# 26    756
# 27    755
# 61    754
# 46    745
# 64    743
# 47    738
# 49    737
# 68    736
# 63    735
# 16    734
# 19    732
# 36    731
# 56    730
# 25    729
# 38    728
# 21    726
# 62    724
# 41    724
# 54    719
# 31    716
# 59    712
# 57    712
# 22    711
# 17    709
# 42    708
# 34    703
# 13    702
# 15    701
# 24    698
# 48    694
# 23    693
# 35    685
# 58    682
# 40    681
# 52    677
# 60    673
# 51    672
# 53    671
# 20    670
# 66    667
# 29    663
# 65    659
# 30    647
# 43    623
# 33    611
# 12    606
# 44    598
# 45    595
# Name: count, dtype: int64

# %%
df.traffic_source.value_counts()
# Out:
# traffic_source
# Search      29339
# Organic      6305
# Facebook     2588
# Email        2156
# Display      1649
# Name: count, dtype: int64

# %%
df.gender.value_counts()
# Out:
# gender
# F    21183
# M    20854
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (42037, 16)

# %%
len("aheng")
# Out:
# 5

# %% [markdown]
# ### 5 Soal dataframes
# 1. Berapakah jumlah pelanggan pria yang berusia lebih dari 25 tahun dan berasal dari negara Brasil?
#
# 2. Traffic Source apa yang mendatangkan paling banyak pelanggan ke The Look ECommerce?
#
# 3. Ada berapa customer yang memiliki nama panjang dengan jumlah karakter lebih dari 20?
#
# 4. Ada berapa total jumlah customer dan total jumlah customer yang melakukan pembelian?
#
# 5. Berapa banyak lost opportunity atau status_order dalam kondisi cancelled dan return yang diterima oleh The Look E-Commerce?

# %%
df
# Out:
#           id         country             nama                       email  \
# 0       9265          Brasil    Eric Phillips    ericphillips@example.org
# 1       9265          Brasil    Eric Phillips    ericphillips@example.org
# 2       9265          Brasil    Eric Phillips    ericphillips@example.org
# 3       9265          Brasil    Eric Phillips    ericphillips@example.org
# 4      13554          Brasil     Brett Flores     brettflores@example.org
# ...      ...             ...              ...                         ...
# 42032  88693  United Kingdom  Bradley Johnson  bradleyjohnson@example.org
# 42033  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42034  98575  United Kingdom  Alexandra Adams  alexandraadams@example.net
# 42035   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
# 42036   7021  United Kingdom    Rebecca Moore    rebeccamoore@example.com
#
#        order_id  order_date traffic_source               category_product  \
# ...

# %%
### 1. Jumlah pelanggan pria > 25 Tahun & negara brasil
dfHasilNo1=df[(df['age']>25) & (df['country']=='Brasil')]
dfHasilNo1
# Out:
#           id country            nama                      email  order_id  \
# 0       9265  Brasil   Eric Phillips   ericphillips@example.org     11630
# 1       9265  Brasil   Eric Phillips   ericphillips@example.org     11630
# 2       9265  Brasil   Eric Phillips   ericphillips@example.org     11630
# 3       9265  Brasil   Eric Phillips   ericphillips@example.org     11630
# 4      13554  Brasil    Brett Flores    brettflores@example.org     17026
# ...      ...     ...             ...                        ...       ...
# 35881  82731  Brasil  Richard Barnes  richardbarnes@example.org    103534
# 35882  92228  Brasil    Jared Howard    jaredhoward@example.com    115415
# 35883  92228  Brasil    Jared Howard    jaredhoward@example.com    115415
# 35884  92228  Brasil    Jared Howard    jaredhoward@example.com    115415
# 35885  92228  Brasil    Jared Howard    jaredhoward@example.com    115415
#
#        order_date traffic_source               category_product  \
# ...

# %%
### Source paling besar dari traffic_source
df.traffic_source.value_counts()
# Out:
# traffic_source
# Search      29339
# Organic      6305
# Facebook     2588
# Email        2156
# Display      1649
# Name: count, dtype: int64

# %%
### Nama lebih dari > 20 karakter
longCustomer=df[df['nama'].apply(len)>20]
longCustomer
# Out:
#           id         country                    nama  \
# 3807     653           China   Christopher Blackburn
# 3808     653           China   Christopher Blackburn
# 3809     653           China   Christopher Blackburn
# 3810     653           China   Christopher Blackburn
# 3811     653           China   Christopher Blackburn
# 3812     653           China   Christopher Blackburn
# 3813     653           China   Christopher Blackburn
# 3814     653           China   Christopher Blackburn
# 4545   48360           China   Christopher Hernandez
# 4546   48360           China   Christopher Hernandez
# 5975   46290   United States   Christopher Whitehead
# 6393   33151   United States   Christopher Hernandez
# 6394   33151   United States   Christopher Hernandez
# 6395   33151   United States   Christopher Hernandez
# 8505   35792         Germany   Christopher Dominguez
# 9025   46332          Brasil   Jacqueline Washington
# 9026   46332          Brasil   Jacqueline Washington
# ...

# %%
print(len('Christopher Washington'))
# Out:
# 22

# %%
### Jumlah customer dan jumlah pembelian customer
print(df['nama'].nunique()) ### nilai yang tidak punya duplikasi / distinct
print(df['id'].nunique())
# Out:
# 16660
# 18746

# %%
### berapa jumlah barang yang retur dan cancelled
print(df['status_order'].unique())
print(df['status_order'].value_counts())
# Out:
# ['Shipped' 'Cancelled' 'Processing' 'Returned' 'Complete']
# status_order
# Shipped       12449
# Complete      10612
# Processing     8293
# Cancelled      6384
# Returned       4299
# Name: count, dtype: int64

# %%
### Nunique = jumlah yang unique atau distince
### unique  = Value-value apa aja yang ada didalam kolom
